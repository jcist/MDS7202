# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # Proyecto: Riesgo en el Banco Giturra
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Gabriel Iturra, Ignacio Meza De La Jara
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# _Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir._
#
# ---
#
# ## Reglas
#
# - Fecha de entrega: 19/12/2023
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ---

# %% [markdown]
# # Presentación del Problema

# %% [markdown]
# ![](https://www.diarioeldia.cl/u/fotografias/fotosnoticias/2019/11/8/67218.jpg)

# %% [markdown]
# **Giturra**, un banquero astuto y ambicioso, estableció su propio banco con el objetivo de obtener enormes ganancias. Sin embargo, su reputación se vio empañada debido a las tasas de interés usureras que imponía a sus clientes. A medida que su banco crecía, Giturra enfrentaba una creciente cantidad de préstamos impagados, lo que amenazaba su negocio y su prestigio.
#
# Para abordar este desafío, Giturra reconoció la necesidad de reducir los riesgos de préstamo y mejorar la calidad de los préstamos otorgados. Decidió aprovechar la ciencia de datos y el análisis de riesgo crediticio. Contrató a un equipo de expertos para desarrollar un modelo predictivo de riesgo crediticio.
#
# Cabe señalar que lo modelos solicitados por el banquero deben ser interpretables. Ya que estos le permitira al equipo comprender y explicar cómo se toman las decisiones crediticias. Utilizando visualizaciones claras y explicaciones detalladas, pudieron identificar las características más relevantes, le permitirá analizar la distribución de la importancia de las variables y evaluar si los modelos son coherentes con el negocio.
#
# Para esto Giturra les solicita crear un modelo de riesgo disponibilizandoles una amplia gama de variables de sus usuarios: como historiales de crédito, ingresos y otros factores financieros relevantes, para evaluar la probabilidad de incumplimiento de pago de los clientes. Con esta información, Giturra podra tomar decisiones más informadas en cuanto a los préstamos, ofreciendo condiciones más favorables a aquellos con menor riesgo de impago.

# %% [markdown]
# ## Instalación de Librerías y Carga de Datos.

# %% [markdown]
# Para el desarrollo de su proyecto, utilice el conjunto de datos `dataset.pq` para entrenar un modelo de su elección. Se le recomienda levantar un ambiente de `conda` para instalar las librerías y así evitar cualquier problema con las versiones.

# %% [markdown]
# ---
#
# ## Secciones Requeridas en el Informe
#
# La siguiente lista detalla las secciones que debe contener su notebook para resolver el proyecto.
# Es importante que al momento de desarrollar cada una de las secciones, estas sean escritas en un formato tipo **informe**, donde describan detalladamente cada uno de los puntos realizados.
#
# ### 1. Introducción [0.5 puntos]
#
# _Esta sección es literalmente una muy breve introducción con todo lo necesario para entender que hicieron en su proyecto._
#
# - Describir brevemente el problema planteado (¿Qué se intenta predecir?)
# - Describir brevemente los datos de entrada que les provee el problema.
# - Describir las métricas que utilizarán para evaluar los modelos generados. Eligan **una métrica** adecuada para el desarrollo del proyecto **según la tarea que deben resolver y la institución a la cuál será su contraparte** y luego justifiquen su elección. Considerando que los datos presentan desbalanceo y que el uso de la métrica 'accuracy' sería incorrecto, enfoquen su elección en una de las métricas precision, recall o f1-score y en la clase que será evaluada.
# - [Escribir al final] Describir brevemente el modelo que usaron para resolver el problema (incluyendo las transformaciones intermedias de datos).
# - [Escribir al final] Indicar si lograron resolver el problema a través de su modelo. Indiquen además si creen que los resultados de su mejor modelo son aceptables y como les fue con respecto al resto de los equipos.
#
# ### 2. Carga de datos Análisis Exploratorio de Datos [Sin puntaje]
#
# _La idea de esta sección es que cargen y exploren el dataset para así obtener una idea de como son los datos y como se relacionan con el problema._
#
# Cargue los datos y realice un análisis exploratorio de datos para investigar patrones, tendencias y relaciones en un conjunto de datos. Se adjuntan diversos scripts para abodar rápidamente este punto. La descripción de las columnas las pueden encontrar en el siguiente [enlace](https://www.kaggle.com/datasets/parisrohan/credit-score-classification).
#
# **NO deben escribir nada**, solo ejecutar el código y encontrar los patrones con los cuales se basaran para generar el modelo.
#
# ### 3. Preparación de Datos [0.5 puntos]
#
# _Esta sección consiste en generar los distintos pasos para preparar sus datos con el fin de luego poder crear su modelo._
#
# #### 3.1 Preprocesamiento con `ColumnTransformer`
#
# - Convierta las columnas mal leidas a sus tipos correspondientes (float, str, etc...)
# - Genere un `ColumnTransformer` que:
#   - Preprocese datos categóricos y ordinales.
#   - Escale/estandarice datos numéricos.
#   - Uitlice `.set_output(transform="pandas")` sobre su `ColumnTransformer` para setear el formato de salida a de las transformaciones a pandas.
#
# - Luego, pruebe las transformaciones utilizando `fit_transform`.
#
# - Posteriormente, ejecute un Holdout que le permita más adelante evaluar los modelos.
#
# #### 3.2 Holdout
#
# Ejecute `train_test_split` para generar un conjunto de entrenamiento, validacióny de prueba.
#
# #### 3.3 Datos nulos.
#
# Como habrá visto, existe la posibilidad de que algunos datos sean nulos. En esta sección se le solicita justificar, previo a comenzar el modelado, decidir si conservar e imputar los datos nulos o eliminar las filas.
#
# Note que la decisión que tomen aquí puede afectar fuertemente el rendimiento de los modelos.
# Y como siempre, más adelante tienen el espacio para experimentar con ambas opciones.
#
# #### 3.4 Feature Engineering [Bonus - 0.5 puntos]
#
# En esta sección, se espera que apliquen su conocimiento y creatividad para identificar y construir características que brinden una mejor orientación a su modelo para identificar los casos deseados. Para motivar la construcción de nuevas características, se recomienda explorar las siguientes posibilidades:
#
# - Generar ratios que relacionen variables categóricas con numéricas. Estos ratios permiten capturar relaciones proporcionales o comparativas entre diferentes categorías y valores numéricos.
# - Combinación de rankings entre variables numéricas y categóricas.
# - Discretización de variables numéricas a categóricas.
# - Etc...
#
# **Importantes**: Al explorar estas posibilidades no se limiten solo a estas propuestas, pueden aplicar otras técnicas de feature engineering pertinentes para mejorar la capacidad de su modelo para comprender y aprovechar los patrones presentes en los datos.
#
# ### 4. Baseline [1.5 puntos]
#
# _En esta sección deben crear los modelos más básicos posibles que resuelvan el problema dado. La idea de estos modelos son usarlos como comparación para que en el siguiente paso lo puedan mejorar._
#
# Implemente, entrene y evalúe varias `Pipeline` enfocadas en resolver el problema de clasificación en donde la diferencia entre estas sea el modelo utilizado.
#
#
# Para esto, cada Pipeline debe:
#
# - Tener el `ColumnTransformer` implementado en la sección anterior como primer paso.
# - Implementar un imputador en caso de haber decidido conservar los datos nulos.
# - Implementar un clasificador en la salida (ver siguiente lista).
#
# Y además,
# - Ser evaluado de forma general imprimiendo un `classification_report`.
# - Calcular y guardar la métrica seleccionada en el punto 1.2 en un arreglo de métricas (guardar nombre y valor de la métrica).
#
# Lo anterior debe ser implementado utilizando los siguientes modelos:
#
# - `Dummy` con estrategia estratificada.
# - `LogisticRegression`.
# - `KNeighborsClassifier`.
# - `DecisionTreeClassifier`
# - `SVC`
# - `RandomForestClassifier`
# - `LightGBMClassifier` (del paquete `lightgbm`)
# - `XGBClassifier` (del paquete `xgboost`).
#
#
# Luego, transformando el diccionario de las métricas a un pandas `DataFrame`, ordene según los valores de su métrica de mayor a menor y responda.
# - ¿Hay algún clasificador entrenado mejor que el azar (`Dummy`)?
# - ¿Cuál es el mejor clasificador entrenado?
# - ¿Por qué el mejor clasificador es mejor que los otros?
# - Respecto al tiempo de entrenamiento, con cual cree que sería mejor experimentar (piense en el tiempo que le tomaría pasar el modelo por una grilla de optimización de hiperparámetros).
#
# **Nota**: Puede utilizar un for más una lista con las clases de los modelos mencionados para simplificar el proceso anterior.
#
#
# ### 5. Optimización del Modelo [1.5 puntos]
#
# _En esta sección deben mejorar del modelo de clasificación al variar los algoritmos/hiperparámetros que están ocupando._
#
# - Instanciar dos nuevas `Pipeline`, similares a la anterior, pero ahora enfocada en buscar el mejor modelo. Para esto, la pipelines debe utilizar el primer y segundo mejor modelo encontrado en el paso anterior.
# - Usar **`Optuna`** para tunear hiperparámetros
# - **Importante**: Recuerden setear la búsqueda para optimizar la métrica seleccionada en los puntos anteriores.
#
# Algunas ideas para mejorar el rendimiento de sus modelos:
#
# - Agregar técnicas de seleccion de atributos/características. El parámetro de cuántas características se seleccionan debe ser parametrizable y configurado por el optimizador de hiperparámetros.
# - Variar el imputador de datos en caso de usarlo.
#
# #### Bonus
#
# 1. **Visualización con Optuna** [0.2 extras]: Explore la documentación de visualización de Optuna en el siguiente [link](https://optuna.readthedocs.io/en/stable/reference/visualization/index.html) y realice un análisis sobre el proceso de optimización de hiperparámetros realizado.
# 2. **Imabalanced learn** [0.3 extras]: Al ser el problema desbalanceado, pueden probar técnicas para balancear automáticamente el dataset previo a ejecutar el modelo. Para esto, puede probar con los mecanismos implementados en la librería [Imbalanced learn](https://imbalanced-learn.org/).
# 3. **Probar pycaret (AutoML)** [0.3 extras].
#
# Algunas notas interesantes sobre este proceso:
#
# - No se les pide rendimientos cercanos al 100% de la métrica para concretar exitosamente el proyecto. Por otra parte, celebren cada progreso que obtengan.
# - **Hacer grillas computables**: Si la grilla se va a demorar 1/3 la edad del universo en explorarse completamente, entonces achíquenla a algo que sepan que va a terminar.
# - Aprovechen el procesamiento paralelo (con `njobs`) para acelerar la búsqueda. Sin embargo, si tienen problemas con la memoria RAM, reduzca la cantidad de jobs a algo que su computador/interprete web pueda procesar.
#
# **Al final de este proceso, seleccione el mejor modelo encontrado, prediga el conjunto de prueba y reporte sus resultados.**

# %% [markdown]
# ### 6. Interpretabilidad [1.0 puntos]
#
# _En esta sección, se espera que los estudiantes demuestren su capacidad para explicar cómo sus modelos toman decisiones utilizando los datos. Dentro del análisis de interpretabilidad propuesto para el modelo, deberán ser capaces de:_
#
# - Proponer un método para analizar la interpretabilidad del modelo. Es crucial que puedan justificar por qué el método propuesto es el más adecuado y explicar los alcances que podría tener en su aplicación.
# - Identificar las características más relevantes del modelo. ¿La distribución de importancia es coherente y equitativa entre todas las variables?
# - Analizar 10 observaciones aleatorias utilizando un método específico para verificar la coherencia de las interacciones entre las características.
# - Explorar cómo se relacionan las variables utilizando algún descriptivo de interpretabilidad.
# - ¿Existen variables irrelevantes en el problema modelado?, ¿Cuales son?.
#
# Es fundamental que los estudiantes sean capaces de determinar si su modelo toma decisiones coherentes y evaluar el impacto que podría tener la aplicación de un modelo con esas variables en una población. ¿Es posible que el modelo sea perjudicial o que las estimaciones se basen en decisiones sesgadas?
#
# En resumen, esta sección busca que los estudiantes apliquen un enfoque crítico para evaluar la interpretabilidad de su modelo, identificar posibles sesgos y analizar las implicaciones de sus decisiones en la población objetivo.
#
# ### 7. Concluir [1.0 puntos]
#
# _Aquí deben escribir una breve conclusión del trabajo que hicieron en donde incluyan (pero no se limiten) a responder las siguientes preguntas:_
#
# - ¿Pudieron resolver exitosamente el problema?
# - ¿Son aceptables los resultados obtenidos?
# - ¿En que medida el EDA ayudó a comprender los datos en miras de generar un modelo predictivo?
#
# Respecto a la clasificación:
#
# - ¿Como fue el rendimiento del baseline para la clasificación?
# - ¿Pudieron optimizar el baseline para la clasificación?
# - ¿Que tanto mejoro el baseline de la clasificación con respecto a sus optimizaciones?
#
# Finalmente:
#
# - ¿Estuvieron conformes con sus resultados?
# - ¿Creen que hayan mejores formas de modelar el problema?
# - ¿En general, qué aprendieron del proyecto? ¿Qué no aprendieron y les gustaría haber aprendido?
#
# **OJO** si usted decide responder parte de estas preguntas, debe redactarlas en un formato de informe y no responderlas directamente.
#
# ### Otras Instrucciones
#
# Recordar el uso de buenas prácticas de MLOPS como replicabilidad (fijar semillas aleatorias) o el uso del registro de experimentos (con MLFlow). Si bien son opcionales, es altamente recomendado su uso.
#
# ### 8. Bonus: Implementación de Kedro y FastAPI [1.5 puntos]
#
# **OPCIONAL**
#
# En esta sección se les solicita utilizar las últimas tecnologías vistas en el curso para la productivización del proyecto de ciencia de datos, centrándose en la organización y gestión de los flujos de trabajo a través de componentes y pipelines, más el servicio del modelo a través del desarrollo de una API.
#
# Para esto:
#
# 1. Genere un proyecto de `Kedro` en donde separe por responsabilidades los nodos/componentes de su proyecto de ciencia de datos en módulos separados. [1.0 puntos]
# 2. Genere un servidor basado en `FastAPI` el cuál a través de un método post, reciba un batch de datos y genere predicciones para cada uno de ellos. [0.5 puntos]
#
# Las implementaciones son libres. Es decir, usted decide qué componentes implementar, como usar el catálogo de datos y la parametrización del flujo. Sin embargo, evaluaremos buen uso de los framework, modularización y separación de responsabilidades.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=87110296-876e-426f-b91d-aaf681223468' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %% [markdown]
# ## Proyecto 2
#
# **Nombres:** Joaquín Cisternas y Diego González
#
#
# ### 1. Introducción
#
# En el siguiente proyecto, se presenta un problema de riesgo de crédito dónde se busca reducir el riesgo de préstamo como tambien mejorar su calidad, para ello se busca predecir la variable `credit_score`a partir de variables relacionadas con la condición de crédito de los clientes, a través de modelos de clasificación binaria.
#
# Los datos a utilizar contienen información sobre el comportamiento de los clientes del banco, como su historial de crédito, ingresos, cantidad de cuentas bancarias; así como también por variables demográficas de interés como su edad y ocupación.
#
# La evaluación de los rendimientos se llevará a cabo considerando como criterio el valor de `F1 score` para la clase positiva, es decir, se elegirá al modelo de clasificación más adecuado para la resolución del problema aquel que posea mayor valor de `F1` para la clase con buena clasificación crediticia.
#
# Para resolver el problema se utilizaron los modelos `lgbm` y `RandomForestClassifier`, los cuales fueron elegidos frente al resto de modelos de clasificación debido a que obtuvieron los dos mejores resultados en `F1 score` para la clase de riesgo crediticio. Antes de utilizar los datos para clasificar, estos fueron pasados por un `ColumnTransformer` donde se aplicó `StandardScaler` a las variables numéricas, `OneHotEncoder` a las variables categóricas y se realizó una imputación de datos faltantes por la media de estos.
#
# Fue posible identificar cuáles fueron las variables más relevantes para determinar el `credit_score`. A pesar de que es un valor aceptable de $\sim 0.6$ de `F1-score` al ajustar los hiperparámetros, no se cree estar entre los mejores ya que faltó realizar un análisis mas extenso de los outliers, sumado a que no se la búsqueda de hipeparámetros fue limitada debido a los altos tiempos de ejecución.

# %% [markdown]
# ### 2. Carga de datos Análisis Exploratorio de Datos [Sin puntaje]

# %%
import pandas as pd
import numpy as np

dataset = pd.read_parquet('dataset.pq')

# %%
dataset.head()
# Out:
#   customer_id   age    occupation  annual_income  monthly_inhand_salary  \
# 0   CUS_0xd40  23.0     Scientist       19114.12            1824.843333
# 1  CUS_0x21b1  28.0       Teacher       34847.84            3037.986667
# 2  CUS_0x2dbc  34.0      Engineer      143162.64           12187.220000
# 3  CUS_0xb891  55.0  Entrepreneur       30689.89            2612.490833
# 4  CUS_0x1cdb  21.0     Developer       35547.71            2853.309167
#
#    num_bank_accounts  num_credit_card  interest_rate  num_of_loan  \
# 0                  3                4              3          4.0
# 1                  2                4              6          1.0
# 2                  1                5              8          3.0
# 3                  2                5              4       -100.0
# 4                  7                5              5       -100.0
#
#    delay_from_due_date  ...  num_credit_inquiries  outstanding_debt  \
# ...

# %%
# analisis exploratorio

dataset.info()

dataset['credit_score'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12500 entries, 0 to 12499
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               12500 non-null  object
#  1   age                       12500 non-null  float64
#  2   occupation                12500 non-null  object
#  3   annual_income             12500 non-null  float64
#  4   monthly_inhand_salary     10584 non-null  float64
#  5   num_bank_accounts         12500 non-null  int64
#  6   num_credit_card           12500 non-null  int64
#  7   interest_rate             12500 non-null  int64
#  8   num_of_loan               12500 non-null  float64
#  9   delay_from_due_date       12500 non-null  int64
#  10  num_of_delayed_payment    11660 non-null  float64
#  11  changed_credit_limit      12246 non-null  float64
#  12  num_credit_inquiries      12243 non-null  float64
# ...

# %%
dataset.describe()
# Out:
#                 age  annual_income  monthly_inhand_salary  num_bank_accounts  \
# count  12500.000000   1.250000e+04           10584.000000       12500.000000
# mean     105.771840   1.616206e+05            4186.634963          16.939920
# std      664.502705   1.297842e+06            3173.690362         114.350815
# min     -500.000000   7.005930e+03             303.645417          -1.000000
# 25%       25.000000   1.945333e+04            1622.408646           3.000000
# 50%       33.000000   3.757238e+04            3087.595000           6.000000
# 75%       42.000000   7.269021e+04            5967.937500           7.000000
# max     8678.000000   2.383470e+07           15204.633333        1756.000000
#
#        num_credit_card  interest_rate   num_of_loan  delay_from_due_date  \
# count     12500.000000   12500.000000  12500.000000         12500.000000
# mean         23.172720      73.213360      3.099440            21.060880
# ...

# %%
# graficos de distribucion

import matplotlib.pyplot as plt

dataset.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ### 3. Preparación de Datos
#
# En el punto anterior, se pudo apreciar que existen `outliers` en ciertas variables, los cuales además de entorpecer el estudio, no tienen sentido alguno, como edades fuera del orden de dos dígitos o números negativos de cuentas bancarias. Aquellos valores se eliminarán antes del preprocesamiento.

# %%
dataset_2 = dataset.copy()

# age
dataset_2 = dataset_2[(dataset_2['age'] > 0) & (dataset_2['age'] < 120)]

# num_bank_accounts
dataset_2 = dataset_2[(dataset_2['num_bank_accounts'] > 0) & (dataset_2['num_bank_accounts'] < 20)]

# num_credit_card
dataset_2 = dataset_2[dataset_2['num_credit_card'] < 20]

# num_of_loan
dataset_2 = dataset_2[(dataset_2['num_of_loan'] > 0) & (dataset_2['num_of_loan'] < 50)]

dataset_2.describe()
# Out:
#                age  annual_income  monthly_inhand_salary  num_bank_accounts  \
# count  9544.000000   9.544000e+03            8096.000000        9544.000000
# mean     33.036777   1.552043e+05            4004.317122           5.749476
# std      10.593654   1.264379e+06            3071.231171           2.380322
# min      14.000000   7.005930e+03             303.645417           1.000000
# 25%      24.000000   1.879813e+04            1564.309271           4.000000
# 50%      33.000000   3.596197e+04            2986.435833           6.000000
# 75%      41.000000   6.948263e+04            5673.364167           8.000000
# max      56.000000   2.383470e+07           15204.633333          11.000000
#
#        num_credit_card  interest_rate  num_of_loan  delay_from_due_date  \
# count      9544.000000    9544.000000  9544.000000          9544.000000
# mean          5.694153      74.687343     4.055008            22.482816
# ...

# %%
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9544 entries, 0 to 12499
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               9544 non-null   object
#  1   age                       9544 non-null   float64
#  2   occupation                9544 non-null   object
#  3   annual_income             9544 non-null   float64
#  4   monthly_inhand_salary     8096 non-null   float64
#  5   num_bank_accounts         9544 non-null   int64
#  6   num_credit_card           9544 non-null   int64
#  7   interest_rate             9544 non-null   int64
#  8   num_of_loan               9544 non-null   float64
#  9   delay_from_due_date       9544 non-null   int64
#  10  num_of_delayed_payment    8915 non-null   float64
#  11  changed_credit_limit      9345 non-null   float64
#  12  num_credit_inquiries      9343 non-null   float64
# ...

# %%
# graficos de distribucion

import matplotlib.pyplot as plt

dataset_2.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# Luego, para la preparación de los datos, se creará una `pipeline` que tenga como primer paso la transformación de las columnas a un formato adecuado, es decir, escalar las variables numéricas como corresponda y transformar las categorías en columnas binarias. Para ello se comienza definiendo qué columnas son numéricas y categóricas.

# %%
# transformación de columnas a categoricas

dataset_2['credit_score'] = dataset_2['credit_score'].astype('category')

# columnas categoricas

cat_cols = ['occupation', 'payment_of_min_amount', 'payment_behaviour']
dataset_2[cat_cols] = dataset_2[cat_cols].astype('category')

# columnas numericas

num_cols = ['age', 'annual_income', 'monthly_inhand_salary',
            'num_bank_accounts', 'num_credit_card', 'interest_rate',
            'num_of_loan', 'delay_from_due_date', 'num_of_delayed_payment',
            'changed_credit_limit', 'num_credit_inquiries', 'outstanding_debt',
            'credit_utilization_ratio', 'credit_history_age',
            'total_emi_per_month', 'amount_invested_monthly', 'monthly_balance']

# %% [markdown]
# #### 3.1 Preprocesamiento con `ColumnTransformer`
#
# Se crea la `pipeline` para el preprocesamiento considerando un caso para las variables numéricas y otro para las categorías. Para las variables numéricas se hace uso del método `StandardScaler`, mientras que para las categorías se utiliza `OneHotEncoder`.

# %%
# importar column transformer

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.feature_selection import SelectPercentile, f_classif
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(sparse_output=False))
])

preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, num_cols),
    ('cat', cat_transformer, cat_cols)],
    remainder='passthrough',
    sparse_threshold = 0)

preprocessor = preprocessor.set_output(transform="pandas")

# Pipeline

from sklearn.pipeline import Pipeline

dataset_processed = preprocessor.fit_transform(dataset.dropna())

dataset_processed.head()
# Out:
#    num__age  num__annual_income  num__monthly_inhand_salary  \
# 1 -0.118843           -0.095194                   -0.346783
# 2 -0.109737           -0.012868                    2.538943
# 3 -0.077866           -0.098355                   -0.480987
# 4 -0.129467           -0.094662                   -0.405031
# 6 -0.109737           -0.021874                    1.997071
#
#    num__num_bank_accounts  num__num_credit_card  num__interest_rate  \
# 1               -0.128637             -0.143345           -0.147365
# 2               -0.137553             -0.135618           -0.143141
# 3               -0.128637             -0.135618           -0.151588
# 4               -0.084059             -0.135618           -0.149476
# 6               -0.146468             -0.166528           -0.143141
#
#    num__num_of_loan  num__delay_from_due_date  num__num_of_delayed_payment  \
# 1         -0.031643                 -1.215320                    -0.124124
# ...

# %% [markdown]
# #### Holdout

# %%
# crear holdout

from sklearn.model_selection import train_test_split

X = dataset_2.drop(['customer_id','credit_score'], axis=1)
y = dataset_2['credit_score']

# crear conjunto de entrenamiento, validacion y prueba

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=123)

# %% [markdown]
# #### 3.3 Datos nulos.
#
# Como se pudo ver al inicio de la sección de preprocesamiento, se decidió filtrar observaciones con valores atípicos, lo cual eliminó algunos de los valores nulos presentes en el conjunto de datos. Para los demás datos sin valores, se decidió imputar utilizando el promedio para las variables numéricas y utilizando la moda para variables categóricas, de esta forma se evita quitar más observaciones de las que ya se descartaron anteriormente.

# %%
dataset_2.isna().sum()
# Out:
# customer_id                    0
# age                            0
# occupation                     0
# annual_income                  0
# monthly_inhand_salary       1448
# num_bank_accounts              0
# num_credit_card                0
# interest_rate                  0
# num_of_loan                    0
# delay_from_due_date            0
# num_of_delayed_payment       629
# changed_credit_limit         199
# num_credit_inquiries         201
# outstanding_debt               0
# credit_utilization_ratio       0
# credit_history_age           848
# payment_of_min_amount          0
# total_emi_per_month            0
# amount_invested_monthly      435
# payment_behaviour              0
# monthly_balance              278
# credit_score                   0
# dtype: int64

# %%
dataset_processed.isna().sum()
# Out:
# num__age                                                   0
# num__annual_income                                         0
# num__monthly_inhand_salary                                 0
# num__num_bank_accounts                                     0
# num__num_credit_card                                       0
# num__interest_rate                                         0
# num__num_of_loan                                           0
# num__delay_from_due_date                                   0
# num__num_of_delayed_payment                                0
# num__changed_credit_limit                                  0
# num__num_credit_inquiries                                  0
# num__outstanding_debt                                      0
# num__credit_utilization_ratio                              0
# num__credit_history_age                                    0
# num__total_emi_per_month                                   0
# ...

# %% [markdown]
# ### 4. Baseline
#
# Se crea una nueva `pipeline` que contempla el preprocesamiento anterior y se le agrega un modelo de clasificación, el cual servirá como `baseline` para futuras optimizaciones de hiperparámetros. Se utilizarán los siguientes modelos de clasificación:
#
# - `Dummy` con estrategia estratificada.
# - `LogisticRegression`.
# - `KNeighborsClassifier`.
# - `DecisionTreeClassifier`
# - `SVC`
# - `RandomForestClassifier`
# - `LightGBMClassifier` (del paquete `lightgbm`)
# - `XGBClassifier` (del paquete `xgboost`).
#
# A continuación, se mostrarán los informes de clasificación para cada modelo y un resumen con el valor de `F1 score` para la clase positiva:

# %%
# modelos de clasificacion

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
import lightgbm as lgb
import time


# Definir la métrica seleccionada (F1 Score para la clase 1)
selected_metric = 'f1_class_1'

metrics_dict = {'Model': [], selected_metric: [], 'f1_class_1_val': [], 'f1_class_1_prom': []}

# definir modelos

models = {
    'Logistic Regression': LogisticRegression(random_state=123),
    'Random Forest': RandomForestClassifier(random_state=123),
    'SVC': SVC(random_state=123),
    'KNN': KNeighborsClassifier(),
    'Dummy Classifier': DummyClassifier(strategy='stratified', random_state=123),
    'Decision Tree': DecisionTreeClassifier(random_state=123),
    'XGB': XGBClassifier(),
    'LGBM': lgb.LGBMClassifier(verbose=0, random_state=123)
}

# Iterar sobre modelos
for model_name, model in models.items():
    # Crear la pipeline para el modelo actual
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('classifier', model)
    ])

    # Iniciar el temporizador
    start_time = time.time()

    # Ajustar la pipeline al conjunto de entrenamiento
    pipeline.fit(X_train, y_train)

    # Detener el temporizador y calcular el tiempo de ejecución
    elapsed_time = time.time() - start_time

    # Realizar predicciones en el conjunto de prueba
    y_pred_test = pipeline.predict(X_test)

    # Calcular la métrica seleccionada en el conjunto de prueba
    f1_class_1_test = f1_score(y_test, y_pred_test, pos_label=1)

    # Realizar predicciones en el conjunto de validación
    y_pred_val = pipeline.predict(X_val)

    # Calcular la métrica seleccionada en el conjunto de validación
    f1_class_1_val = f1_score(y_val, y_pred_val, pos_label=1)

    # Imprimir classification_report, tiempo de ejecución y métrica en conjunto de validación
    print(f"Classification Report for {model_name} (Test Set):\n", classification_report(y_test, y_pred_test, zero_division=1))
    print(f"Classification Report for {model_name} (Validation Set):\n", classification_report(y_val, y_pred_val, zero_division=1))
    print(f"Elapsed Time for {model_name}: {elapsed_time} seconds")
    print(f"F1 Score for {model_name} (Test Set): {f1_class_1_test}")
    print(f"F1 Score for {model_name} (Validation Set): {f1_class_1_val}\n")

    # Guardar las métricas en el diccionario
    metrics_dict['Model'].append(model_name)
    metrics_dict[selected_metric].append(f1_class_1_test)
    metrics_dict['f1_class_1_val'].append(f1_class_1_val)
    metrics_dict['f1_class_1_prom'].append((f1_class_1_test + f1_class_1_val)/2)

# Convertir el diccionario de métricas a un DataFrame
metrics_df = pd.DataFrame(metrics_dict)

# Ordenar el DataFrame por el valor de la métrica de mayor a menor
metrics_df = metrics_df.sort_values(by=selected_metric, ascending=False)

# Imprimir el DataFrame ordenado
print("\nMetrics DataFrame:")
metrics_df
# Out:
# Classification Report for Logistic Regression (Test Set):
#                precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82      1316
#            1       0.59      0.38      0.46       593
#
#     accuracy                           0.73      1909
#    macro avg       0.67      0.63      0.64      1909
# weighted avg       0.71      0.73      0.71      1909
#
# Classification Report for Logistic Regression (Validation Set):
#                precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82      1275
#            1       0.68      0.40      0.50       634
#
#     accuracy                           0.74      1909
#    macro avg       0.72      0.65      0.66      1909
# weighted avg       0.73      0.74      0.72      1909
#
# Elapsed Time for Logistic Regression: 0.0533144474029541 seconds
# F1 Score for Logistic Regression (Test Set): 0.4631147540983606
# ...

# %% [markdown]
# Es posible ver que todos los modelos en su `baseline` clasifican mejor que el `Dummy` para la métrica escogida, destacando el rendimiento de `LGBM` y `Random Forest`, que llegan a 0.60 pts al promediar entre el conjunto de prueba y validación. Es probable que el rendimiento de estos modelos haya sido superior al resto debido a su construcción, siendo ambos algoritmos basados en el ensamble de árboles, combinando sus predicciones para mejorar el rendimiento general del modelo.
#
# Con respecto al tiempo de entrenamiento, el modelo que toma más tiempo en entrenarse es `Random Forest` con 3 segundos, mientras que `LGBM` solo toma 0.2 segundos. Debido a esto, y a los valores de `baseline`, el modelo más adecuado a optimizar sus hiperparámetros es `LGBM`.

# %% [markdown]
# #### 5. Optimización del Modelo
#
# En esta sección se toman como modelos a optimizar `LGBM` y `Random Forest`, dónde se actualizarán sus hiperparámetros más relevante utilizando el framework `optuna`. Se realizarán 100 iteraciones para encontrar la configuración que mejore los valores para ambos modelos.
#
# Para ello, se definen dos funciones objetivo, una por cada modelo a optimizar con los hiperparámetros de interés y los valores en los que se buscará el mejor rendimiento de `F1 score`. Al igual que en las secciones anteriores, los modelos se trabajarán a través de una pipeline, la cual esta vez posee un término extra que realiza selección de características según el percentil de aporte al `F1 score`.

# %%
# pip install -U imbalanced-learn

# %%
# features = SelectPercentile(score_func = f_classif, percentile = 90)

# %%
# optimizacion de hiperparametros

import optuna
from sklearn.metrics import make_scorer
from sklearn.feature_selection import SelectPercentile, f_classif

# metrica a optimizar

selected_metric = 'f1_class_1'

# crear una funcion que retorne f1 para la clase 1

def f1_class_1(y_true, y_pred):
    return f1_score(y_true, y_pred, pos_label=1)

scorer = make_scorer(f1_class_1)

# crear funcion para optimizar lgbm

def objective_lgbm(trial):
    # Crear un diccionario con los parámetros
    params = params = {'num_leaves': trial.suggest_int('num_leaves', 20, 150),
                       'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.05),
                       'max_depth': trial.suggest_int('max_depth', 2, 256),
                       'features__percentile': trial.suggest_int('features__percentile', 20, 100),
                       'min_child_samples': trial.suggest_int('min_child_samples', 2, 256),
                       'min_child_weight': trial.suggest_int('min_child_weight', 0.1, 0.5),
                       'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
                       'percentile': trial.suggest_int('percentile', 20, 100),
                       }

    # Crear la pipeline con los parámetros
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('features', SelectPercentile(f_classif, percentile=params['percentile'])),
        ('classifier', lgb.LGBMClassifier(**params, verbose=-1, random_state=123))
    ])

    pipeline.fit(X_train, y_train)

    # Calcular el score en el conjunto de prueba
    score_test = f1_class_1(y_test, pipeline.predict(X_test))

    # Calcular el score en el conjunto de validación
    score_val = f1_class_1(y_val, pipeline.predict(X_val))

    # Tomar la media de los scores de prueba y validación
    final_score = (score_test + score_val) / 2

    return final_score

# crear funcion para optimizar random forest

def objective_rf(trial):
    # Crear un diccionario con los parámetros
    params = {'bootstrap': True,
              'ccp_alpha': trial.suggest_float('ccp_alpha', 0.0, 0.5),
              'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample', None]),
              'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss']),
              'max_depth': trial.suggest_int('max_depth', 2, 256),
              'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 2, 256),
              'min_impurity_decrease': trial.suggest_float('min_impurity_decrease', 0.0, 0.5),
              'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
              'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
              'min_weight_fraction_leaf': trial.suggest_float('min_weight_fraction_leaf', 0.0, 0.5),
              'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
              }

    features_params = {
        'percentile': trial.suggest_int('percentile', 20, 100)
    }

    # Crear la pipeline con los parámetros
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('features', SelectPercentile(f_classif, **features_params)),
        ('classifier', RandomForestClassifier(**params, random_state=123))
    ])

    pipeline.fit(X_train, y_train)

    # Calcular el score en el conjunto de prueba

    score_test = f1_class_1(y_test, pipeline.predict(X_test))

    # Calcular el score en el conjunto de validación

    score_val = f1_class_1(y_val, pipeline.predict(X_val))

    # Tomar la media de los scores de prueba y validación

    final_score = (score_test + score_val) / 2

    return final_score

# %%
# optimizar lgbm

import warnings

optuna.logging.set_verbosity(optuna.logging.WARNING)

#warnings.filterwarnings("ignore", category=lgb.LGBMWarning)

study_lgbm = optuna.create_study(direction='maximize')
study_lgbm.optimize(objective_lgbm, n_trials=100, show_progress_bar=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# Al terminar la optimización de `LGBM`, es posible ver que el mejor valor de `F1 score` se encuentra en la iteración 94, obteniendo un valor de 0.618 pts, mejorando el valor promedio pre-optimización.

# %%
# obtener los mejores parametros

study_lgbm.best_params
# Out:
# {'num_leaves': 63,
#  'learning_rate': 0.010295119089936558,
#  'max_depth': 9,
#  'features__percentile': 44,
#  'min_child_samples': 123,
#  'min_child_weight': 0,
#  'n_estimators': 531,
#  'percentile': 96}

# %% [markdown]
# A continuación se encuentra el historial de valores obtenidos a lo largo de las 100 iteraciones, mostrando que el valor máximo de `F1 score` crece lentamente a lo largo del proceso.

# %%
optuna.visualization.plot_optimization_history(study_lgbm)

# %%
# optimizar random forest

study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective_rf, n_trials=100, show_progress_bar=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# Por otro lado, con `Random Forest` se obtiene un `F1 score` de 0.649 pts en la iteración 94, mejorando notablemente el valor de la `baseline`.

# %%
# obtener los mejores parametros

study_rf.best_params
# Out:
# {'ccp_alpha': 0.027482147885714975,
#  'class_weight': 'balanced_subsample',
#  'criterion': 'entropy',
#  'max_depth': 253,
#  'max_leaf_nodes': 166,
#  'min_impurity_decrease': 0.005731902570815201,
#  'min_samples_leaf': 6,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.17318720170810295,
#  'n_estimators': 995,
#  'percentile': 94}

# %% [markdown]
# Al graficar, es posible apreciar como los valores se incrementan considerablemente desde la iteración 20, donde el valor se estabiliza, creciendo lentamente. Mostrando que es posible entrenar al modelo en menos iteraciones y obtener el resultado similar en menor tiempo.

# %%
# graficar optimizacion

optuna.visualization.plot_optimization_history(study_rf)

# %% [markdown]
# Finalmente, se elige `Random Forest` para evaluar el modelo y ver como mejoran los resultados con los parámetros optimizados.

# %%
# estimar el modelo con los mejores parametros

rf_params = study_rf.best_params.copy()
rf_params.pop('percentile')

best_model_rf = RandomForestClassifier(**rf_params, random_state=123)

# crear pipeline con los mejores modelos

pipeline_rf = Pipeline([
    ('preprocessor', preprocessor),
    ('features', SelectPercentile(f_classif, percentile=study_rf.best_params['percentile'])),
    ('classifier', best_model_rf)
])

# ajustar los modelos

pipeline_rf.fit(X_train, y_train)

# realizar predicciones

y_pred_rf = pipeline_rf.predict(X_test)

# imprimir classification report

print(f"Classification Report for RF:\n", classification_report(y_test, y_pred_rf, zero_division=1))
# Out:
# Classification Report for RF:
#                precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77      1316
#            1       0.53      0.73      0.61       593
#
#     accuracy                           0.71      1909
#    macro avg       0.69      0.72      0.69      1909
# weighted avg       0.75      0.71      0.72      1909

# %% [markdown]
# Es posible apreciar como aumenta el `F1 score` para la clase con mayor riesgo en comparación al modelo sin optimizar, pasado de 0.54 a 0.61 en el conjunto de prueba. Esto muestra una mejora en el rendimiento bajo el criterio definido anteriormente. A continuación, se guardará el modelo y sus parámetros.

# %%
# guardar el mejor modelo

import pickle

with open('best_model_lgbm.pkl', 'wb') as f:
    pickle.dump(pipeline_rf, f)

# %%
import shap

# crear un objeto explainer

explainer = shap.TreeExplainer(pipeline_rf['classifier'])

# transformar X_test con el preprocesador

X_test_processed = pipeline_rf['preprocessor'].transform(X_test)

# seleccionar las columnas segun el selector de variables

selected_features = pipeline_rf['features'].get_support()

column_names_selected = X_test_processed.columns[selected_features]

X_test_processed = pipeline_rf['features'].transform(X_test_processed)

X_test_processed = pd.DataFrame(X_test_processed, columns=column_names_selected)

# calcular los valores de shapley

shap_values = explainer(X_test_processed)

# %% [markdown]
# #### 6. Interpretabilidad

# %%
# grafico de importancia de variables

shap.summary_plot(shap_values[:,:,1], X_test_processed, plot_type="bar", feature_names=X_test_processed.columns)

# %% [markdown]
# Es posible notar que las dos variables más relevantes son `outstanding_debt`, `interest_rate` y `delay_from_due_date`. Estas son variables que se relacionan con los hábitos financieros de los clientes, por lo que tiene sentido.

# %% [markdown]
# Se analizan 10 observaciones aleatorias utilizando el método `waterfall` de Shap Values.

# %%
secuencia = np.arange(1, shap_values.shape[0])

# 10 datos al azar
intancias_aleatorias = np.random.choice(secuencia, size=10, replace=False)

for i in intancias_aleatorias:
  shap.plots.waterfall(shap_values[i,:,1], max_display=11)

# %% [markdown]
# Es posible observar que las características que más aportan, en general, son las que estan relacionadas con el historial crediticio e ingresos de las personas, aunque hay otras características como la edad que toma una gran relevancia en algunos casos. En general no se observan inconsistencias en como afectan estas variables a `credit_score`.

# %% [markdown]
# Mediante el uso de scatter plots, se analizará la correlación entre las variables.

# %%
shap_values_abs = np.mean(np.abs(shap_values.values[:,:,1]), axis=0)
feature_importance_names = X_test_processed.columns[shap_values_abs.argsort()[::-1]]

# Scatter Plot
for name in feature_importance_names[:50]:
    shap.plots.scatter(shap_values[:, name, 1])
    print('')

# %% [markdown]
# Es posible notar que bajos valores de `outstanding_debt` se tienen clientes menos riesgosos, con shap values negativos que aumentan drásticmente después de un umbral.
#
# Se aprecia que aumentos en `delay_from_due_date`,`num_of_loan`, `num_of_bank_accounts` y `num_credit_card` se relacionan con clientes más riesgosos.
#
# Con respecto a `changed_credit_limit`,`credit_history_age`, se tiene que cuando estas variables aumentan disminuyen los shap values, por lo que los clientes son menos riesgosos. Aunqe para este último valores bajos no tienen una relación muy clara.

# %% [markdown]
# Para identificar variables irrelevantes se calculará la media del valor absoluto de los shap_values. Los valores iguales a cero indican la irrelevancia de las variables.

# %%
# Shap Absoluto
shap_abs_variables = np.mean(np.abs(shap_values.values[:,:,1]), axis=0)
shap_abs_variables
# Out:
# array([2.37176089e-04, 9.40984991e-04, 8.12722718e-04, 8.56596284e-03,
#        5.54087795e-03, 3.35292595e-02, 1.09876295e-02, 1.03804940e-02,
#        3.20363078e-03, 5.44228602e-05, 1.91355956e-02, 3.71964807e-02,
#        0.00000000e+00, 1.16500035e-02, 0.00000000e+00, 2.29298567e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.46630876e-03,
#        4.24880735e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.46628441e-04])

# %% [markdown]
# Es posible notar que existe una gran cantidad de variables irrelevantes, lo cual tiene sentido con lo observado, pues al momento de optimizar el valor del percentil de corte, este se encuentra cercano al 100, lo que muestra que toma gran mayoría de las variables y las incluye en el modelo. Por otra parte, se puede apreciar que en los gráficos de los shap values por variable, gran cantidad de ellas (en particular las categóricas con `OneHotEncoding`) no tenían variación en sus valores. Las columnas irrelevantes son las siguientes:

# %%
# retornar las columnas irrelevantes

columnas_irrelevantes = X_test_processed.columns[shap_abs_variables < 0.01]

# imprimir las columnas irrelevantes

columnas_irrelevantes
# Out:
# Index(['num__age', 'num__annual_income', 'num__monthly_inhand_salary',
#        'num__num_bank_accounts', 'num__num_credit_card',
#        'num__num_of_delayed_payment', 'num__changed_credit_limit',
#        'num__credit_utilization_ratio', 'num__total_emi_per_month',
#        'num__amount_invested_monthly', 'num__monthly_balance',
#        'cat__occupation_Accountant', 'cat__occupation_Architect',
#        'cat__occupation_Developer', 'cat__occupation_Doctor',
#        'cat__occupation_Engineer', 'cat__occupation_Entrepreneur',
#        'cat__occupation_Journalist', 'cat__occupation_Manager',
#        'cat__occupation_Mechanic', 'cat__occupation_Media_Manager',
#        'cat__occupation_Musician', 'cat__occupation_Scientist',
#        'cat__occupation_Teacher', 'cat__occupation_Writer',
#        'cat__payment_of_min_amount_No', 'cat__payment_of_min_amount_Yes',
#        'cat__payment_behaviour_!@9#%8',
#        'cat__payment_behaviour_High_spent_Large_value_payments',
# ...

# %% [markdown]
# #### 7. Conclusiones

# %% [markdown]
# Mediante el uso de herramientas de minería de datos, fue posible identificar las variables más relevantes para predecir el `credit_score` de un cliente. Estas fueron `outstanding_debt` y `delay_from_due_date`. El uso de esta información es útil para manejar de mejor manera el riesgo de los créditos que ofrece la empresa.
#
# Respecto al desempeño de los modelos de clasificación, es posible ver que todos los modelos en su `baseline` clasifican mejor que el `Dummy` para la métrica escogida, destacando el rendimiento de `LGBM` y `Random Forest`, que llegan a 0.60 pts al promediar entre el conjunto de prueba y validación. Luego de la selección de hiperparámetros mediante `Optuna Search`, el método `Random Forest` obtiene un `F1 score` de 0.652 pts, mejorando notablemente el valor de la `baseline`, al igual que `LGBM`, en donde el mejor valor de `F1 score` fue de 0.62 pts, mejorando el valor promedio pre-optimización, aunque no mejor que `Random Forest`.
#
# En resumen, se puede concluir que los resultados obtenidos ofrecen la posibilidad de mejorar la situación actual de la empresa. No obstante, se plantea la opción de modelar el límite máximo del crédito asignado a un cliente considerando su riesgo y capacidad de pago. Esto se debe a que la simplificación de clasificaciones binarias en el problema de riesgo crediticio podría no capturar completamente la complejidad de la situación, especialmente dado que el mejor modelo entrenado no logró alcanzar una métrica muy alta.
